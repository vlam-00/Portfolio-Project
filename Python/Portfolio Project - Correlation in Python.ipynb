# %%
# Portfolio Project - Correlation in Python
# Using Python to find correlations between variables in a dataset for my protfolio project.
# ----------------------------------------------------------------------------------------------------
# NOTE:  Will be using the ".head()" function to limit the amount of data displayed since this is just a smaple of my work

# %%
# Importing the libraries and packages
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  # Adjusts the configuration of the plots we will create

pd.options.mode.chained_assignment = None


# Read in the data
df = pd.read_csv(r'movies.csv')

# %%
# Previwing the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Determine if there is missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {:.2f}%'.format(col, pct_missing*100))
# Out:
# name - 0.00%
# rating - 1.00%
# genre - 0.00%
# year - 0.00%
# released - 0.03%
# score - 0.04%
# votes - 0.04%
# director - 0.00%
# writer - 0.04%
# star - 0.01%
# country - 0.04%
# budget - 28.31%
# gross - 2.46%
# company - 0.22%
# runtime - 0.05%

# %%
# Fill all null values with 0
##df_filled = df.fillna(0)
##print(df_filled)

## df.fillna(0)
##print(df)

df['votes'] = df['votes'].fillna(0)
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0)
df['runtime'] = df['runtime'].fillna(0)
df.head(20)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
# Identify data types in our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Convert the data in the columns to the proper data type
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Split the released column into a date and country column
df['released'] = df['released'].astype('str')
text = df['released']
delimiter = "("
df[['released_date', 'released_country']] = text.str.split(delimiter, expand=True)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Create a new adjusted year column based on the relased date and clean the relased country values
string = df['released_date']
df['released_year'] = string.str.strip(" ").str[-4:]
df['released_country'] = df['released_country'].astype(str).str[:-1]
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score    votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000     Stanley Kubrick
# ...

# %%
# View data sorted by gross value
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score    votes       director  \
# ...

# %%
# View the entire dataset
##pd.set_option('display.max_rows', None)
##df
# NOTE: This has been commented out to avoid 7500+ rows of data showing on the github page.

# %%
# Drop duplicates
df['company'].drop_duplicates().sort_values(ascending=False).head()
# Out:
# 7129                     thefyzz
# 5664                 micro_scope
# 6412    iDeal Partners Film Fund
# 4007                    i5 Films
# 6793                  i am OTHER
# Name: company, dtype: object

# %%
# Scatter plot with budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Film Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Sort the data and view top values
df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot budget vs gross using seaborn
##sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color": "steelblue"}, line_kws={"color": "palegoldenrod"})
sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color": "k"}, line_kws={"color": "gold"})
plt.title('Budget vs Gross Earnings')
plt.xlabel('Film Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Determine correlation and showing off the different correlation methods
##df.corr()
##df.corr(method='pearson')
##df.corr(method='kendall')
##df.corr(method='spearman')
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222427  0.309212  0.261900  0.116358
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.398387
# votes    0.222427  0.409182  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.055665  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186392  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.398387  0.306984  0.268372  0.244339  1.000000

# %%
# Creating a heatmap based on the correlation matrix
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Columns')
plt.show()

# %%
# Convert all text to numeric values
df_numerized = df
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype("category")
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000      1155    1778
# 7445   535       5      0  2019       183    8.4   903000       162     743
# 3045  6896       5      6  1997       704    7.8  1100000      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000      1125    2550
# 7244   536       5      0  2018       192    8.4   897000       162     743
#
#       star  country     budget       gross  company  runtime  released_date  \
# 5445  2334       55  237000000  2847246203     2253      162            610
# 7445  2241       55  356000000  2797501328     1606      181            153
# 3045  1595       55  200000000  2201647264     2253      194            616
# 6663   524       55  245000000  2069521700     1540      138            612
# 7244  2241       55  321000000  2048359754     1606      149            161
#
#       released_country  released_year
# ...

# %%
# Creating a heatmap based on the correlation matrix for all columns
correlation_matrix = df_numerized.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for all Columns')
plt.show()

# %%
# Un-pivoting the correlation matrix into a tabular format
correlation_matrix = df_numerized.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.010480
# dtype: float64

# %%
# Sort and pair data by correlation
sorted_pairs = corr_pairs.sort_values()
sorted_pairs.head()
# Out:
# genre   budget   -0.334021
# budget  genre    -0.334021
# gross   genre    -0.234297
# genre   gross    -0.234297
#         votes    -0.145296
# dtype: float64

# %%
# Filter by high corerlating items
high_corr = sorted_pairs[(sorted_pairs ) > 0.5]
high_corr
# Out:
# gross             votes               0.632870
# votes             gross               0.632870
# budget            gross               0.750157
# gross             budget              0.750157
# year              released_year       0.997295
# released_year     year                0.997295
# released_date     released            0.999912
# released          released_date       0.999912
# rating            rating              1.000000
# company           company             1.000000
# writer            writer              1.000000
# director          director            1.000000
# budget            budget              1.000000
# released_country  released_country    1.000000
# star              star                1.000000
# country           country             1.000000
# gross             gross               1.000000
# released_date     released_date       1.000000
# released          released            1.000000
# score             score               1.000000
# ...
